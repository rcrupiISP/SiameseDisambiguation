# %% [markdown]
# # Company dataset from LLM

# %% [markdown]
# ### Download companies from here https://www.kaggle.com/datasets/peopledatalabssf/free-7-million-company-dataset?resource=download

# %% [markdown]
# ### Prompt test

# %%
# Example
list_company_name = ['Ferrero', 'Amazon', 'Ferrari']

# %%
def get_prompt(list_company_name):

  return f"""
You are an expert in company names and their aliases. You will assist me in building a precise dataset of company names and their aliases.

For instance, the company "Intesa Sanpaolo" can be written in various ways such as "Intesa Sanpaolo", misspelled as "Intesa San Paolo", abbreviated as "ISP", or with its legal entity name "Intesa Sanpaolo S.p.A." Similarly, "Fiat Chrysler Automobiles" can be abbreviated as "FCA".

In cases where companies have merged, such as "Stellantis", it should be recognized as the same company as "Fiat Chrysler Automobiles" and "Peugeot". For temporary joint ventures like "Nokia and Siemens", they should not be confused as a single entity but recognized as separate companies.

Also, note that "OpenAI" and "Microsoft" are distinct companies, even though Microsoft leverages OpenAI products.

For each company name, provide one or more aliases including possible, abbreviations, acronyms, patents, and official documents, among others. Accuracy and precision in your work are essential, our lives and happiness depend on this.
If you don't have any correct aliases to match, please do not include them.

Ensure that the names you associate with a company are effectively real aliases or representations of that company.

You will receive a list of company names such as ['FCA', 'Intesa Sanpaolo', 'OpenAI'] and you should return only a CSV table formatted with only two fields: company name, alias company name.
If you have multiple aliases for the same company, add each alias on the next row while maintaining the two columns.

The output style should be simple (no title, comments or markdown style) only like this:

FCA, Fiat Chrysler Automobiles
Intesa Sanpaolo, ISP
Intesa Sanpaolo, Intesa San Paolo
OpenAI, Open AI
Stellantis, FCA

----------------------------------------------------------

List of company names: {list_company_name}

"""

prompt = get_prompt(list_company_name)

# To set more typos in the name you can add 'common names in news' in the list of possible source. You can furhter remove 'misspellings' to be more precise.

# %%
# Register here and get the secret key for free https://www.awanllm.com/

from google.colab import userdata
AWANLLM_API_KEY = userdata.get('awan')

import requests
import json

url = "https://api.awanllm.com/v1/chat/completions"

payload = json.dumps({
  "model": "Awanllm-Llama-3-8B-Dolfin",
  "messages": [
    {
      "role": "user",
      "content": prompt
    }
  ],
  "max_tokens": 1024,
  "temperature": 0.7
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': f"Bearer {AWANLLM_API_KEY}"
}

response = requests.request("POST", url, headers=headers, data=payload)

# %%
print(json.loads(response.text)['choices'][0]['message']['content'])
# Out:
# Ferrero, Ferrero SpA
# Ferrero, Nutella
# Ferrero, Kinder
# Ferrero, Tic Tac
# Amazon, AMZN
# Amazon, Amazon Web Services
# Amazon, AWS
# Amazon, Zappos
# Amazon, Whole Foods Market
# Amazon, Twitch
# Amazon, Audible
# Amazon, IMDb
# Amazon, Goodreads
# Amazon, Amazon Studios

# %% [markdown]
# ## Loop for dataset creation

# %%
import pandas as pd
# df = pd.read_csv('companies_sorted.csv')
# df_ita = df[df.country=='italy']
# list_company_name = df_ita.name[0:300].values

# %%
list_company_name = ['saipem', 'unicredit', 'leonardo', 'eni', 'intesa sanpaolo',
       'telecom italia', 'poste italiane', 'enel', 'luxottica', 'ibest',
       'libero  professionista', 'ministero della difesa',
       'world food programme', 'pirelli', 'magneti marelli', 'fao',
       'gucci', 'university of rome "la sapienza"',
       'bnl gruppo bnp paribas', 'banca monte dei paschi di siena',
       'university of padova', 'engineering ingegneria informatica spa',
       'university of milan', 'prada',
       'alitalia compagnia aerea italiana spa', 'banca mediolanum',
       'comau', 'iveco', 'costa crociere', 'ferrari', 'prysmian group',
       'trenitalia s.p.a.', 'me stessa', 'university of florence',
       'consiglio nazionale delle ricerche', 'studio commercialista',
       'banco popolare', 'unipolsai assicurazioni spa',
       'arma dei carabinieri', 'gi group', 'ubi banca', 'banca fideuram',
       'sky italia', 'ied istituto europeo di design',
       'politecnico di milano', 'università degli studi di torino',
       'ansaldo sts', 'sunglass hut', 'politecnico di torino',
       'almaviva s.p.a.', 'university of naples federico ii',
       'dolce&gabbana s.r.l', 'benetton group', 'alleanza assicurazioni',
       'wind', 'calzedonia group', 'finecobank', 'university of pisa',
       'mediaset', 'rfi rete ferroviaria italiana', 'diesel', 'fastweb',
       'university of rome "tor vergata"', 'whirlpool emea', 'danieli',
       'mondadori', 'comune', 'inail', 'chiesi group', 'allianz italia',
       'university of bologna', 'barilla group', "banca d'italia",
       'bulgari', 'piaggio group', 'menarini group',
       'libero professionista geometra', 'pwc italy',
       'fincantieri s.p.a.', 'polizia di stato',
       'università degli studi di milano-bicocca', 'salini impregilo',
       'egencia', 'ntt data italia', 'esselunga', 'university of pavia',
       'agenzia delle entrate', 'cheil worldwide', 'dental clinic',
       'università degli studi di bari', 'accenture italia',
       'ermenegildo zegna group', 'università degli studi roma tre',
       'rina', 'ansaldo energia', 'banca popolare di milano',
       "università degli studi di roma 'la sapienza'", 'valentino',
       'indesit company', 'salvatore ferragamo', 'max mara fashion group',
       'maserati', 'bper banca', 'astaldi', 'università bocconi',
       'gruppo cariparma crédit agricole', 'libre', 'amplifon',
       'kpmg italy', 'safilo', 'enel green power',
       'marche sub di cristobal alvarez rodolfo', 'university of trento',
       'università degli studi di palermo', 'bonatti s.p.a.',
       'unipol assicurazioni', 'university of modena and reggio emilia',
       'decathlon italia', 'avio aero', 'business integration partners',
       'studio tecnico ing. riccardo tognarini e centro promozionale efficienza in edilizia',
       'unicredit business integrated solutions',
       'reale mutua assicurazioni', 'rcs mediagroup', 'fendi',
       'il sole 24 ore', 'enea', 'brembo s.p.a.', 'banco bpm', 'lavazza',
       'geox', 'h3g', 'credem banca', 'ariston thermo group',
       'deloitte italia', 'ferrovie dello stato s.p.a.', 'gruppo campari',
       'sirti', 'ministero delle infrastrutture e trasporti', 'a2a',
       'banca generali', 'cattolica assicurazioni', 'lidl italia',
       'provincia autonoma di trento', 'zambon', 'bottega veneta',
       'kiko milano', 'comune di roma', 'deutsche bank italia', 'anas',
       'croce rossa italiana',
       'scuola superiore della pubblica amministrazione',
       'automobili lamborghini s.p.a.', 'sogefi group', 'sia s.p.a.',
       'policlinico umberto i', 'datalogic', 'scuola normale superiore',
       'technogym', 'university of verona', 'wind tre', 'randstad italia',
       'comdata spa', 'regione emilia-romagna', 'italtel',
       'libera professione', 'apss trento', 'crif',
       'università politecnica delle marche', 'edison spa',
       'seat pagine gialle spa', 'infn', 'banca ifis', 'regione lazio',
       'istituto clinico humanitas', 'psicologia', 'ilva spa', 'azimut',
       'credito valtellinese', 'hera', 'italiaonline', 'angelini',
       'diasorin',
       'ministero dei beni e delle attività culturali e del turismo',
       'permasteelisa spa', 'studio professionale', 'atac spa', 'bticino',
       'terna', 'rai - radiotelevisione italiana s.p.a.',
       'axa assicurazioni', 'exprivia', 'indipendente', 'miroglio',
       'ministero pubblica istruzione', 'electrolux professional',
       'istituto italiano di tecnologia', "scuola superiore sant'anna",
       'banca popolare di vicenza', 'italcementi group', 'artsana group',
       'istat', 'university of catania', 'veneto banca',
       'groupama assicurazioni s.p.a.', 'ovs', 'university of messina',
       'loro piana', 'international fund for agricultural development',
       'fpt industrial', 'fondazione don carlo gnocchi onlus',
       "de'longhi", 'chebanca! s.p.a - gruppo mediobanca',
       'gruppo banca sella', 'snam rete gas', 'bracco', 'acea spa',
       'varie', 'moncler', "autostrade per l'italia", 'fondiaria-sai',
       'mcs', 'comune di bologna', 'mediamarket s.p.a.',
       'agos ducato spa', 'university of calabria', 'law firm',
       'versalis spa', 'regione piemonte', 'ssc', 'banca imi',
       'biesse group', 'medisur', 'enav', 'university of salerno',
       'candy hoover group', 'luiss', 'university of perugia',
       'teamsystem', 'università del salento', 'la perla',
       'ericsson it solutions & services spa', 'ducati motor holding',
       'zucchetti', 'azienda ospedaliera universitaria integrata verona',
       'sisal s.p.a.', 'sanpaolo invest sim s.p.a.', 'unieuro',
       'fondazione i.r.c.c.s. policlinico san matteo pavia',
       'fincons group', 'banca carige spa', 'techedge group', 'sogei',
       'maire tecnimont', 'mediobanca', 'unipol banca', 'conad',
       'recordati', 'comune di firenze', 'university of siena',
       'fater s.p.a.', 'natuzzi', 'sol', 'banca popolare di sondrio',
       'università degli studi di cagliari', 'coop alleanza 3.0',
       'presidenza del consiglio dei ministri',
       'sara assicurazioni s.p.a.', 'sacmi',
       'ieo istituto europeo di oncologia', 'vittoria assicurazioni',
       'mine', 'scm group spa', 'sdl centrostudi s.p.a.',
       'italferr s.p.a.', 'alten italia', 'italia lavoro', 'csi piemonte',
       'sielte s.p.a.', 'sda express courier', 'findomestic banca spa',
       'sorin group', 'camera dei deputati',
       'regione autonoma friuli venezia giulia',
       'sda bocconi school of management', 'frau', 'coldiretti',
       'wolters kluwer italia', 'marcolin', 'university of udine',
       'bonfiglioli', 'mondo convenienza',
       'zoppas industries heating element technologies',
       'università degli studi di parma', 'same deutz-fahr group',
       'telespazio', 'furla', 'würth italia', 'gea', 'manutencoop']

# %%
import time

dataset_alias = 'Company Name, Alias\n'

STEP=5
for i in range(0, len(list_company_name), STEP):
  try:
      list_company_name_tmp = list_company_name[i:i+STEP]

      url = "https://api.awanllm.com/v1/chat/completions"

      payload = json.dumps({
        "model": "Awanllm-Llama-3-8B-Dolfin",
        "messages": [
          {
            "role": "user",
            "content": get_prompt(list_company_name_tmp)
          }
        ],
        "max_tokens": 1024,
        "temperature": 0.7
      })
      headers = {
        'Content-Type': 'application/json',
        'Authorization': f"Bearer {AWANLLM_API_KEY}"
      }

      response = requests.request("POST", url, headers=headers, data=payload)

      print(json.loads(response.text)['choices'][0]['message']['content'])

      dataset_alias += json.loads(response.text)['choices'][0]['message']['content'] + '\n'

      time.sleep(6)
  except Exception as e:
      print(e)
      time.sleep(6)
# Out:
# 'choices'
# telecom italia, Telecom Italia S.p.A.
# poste italiane, Poste Italiane
# enel, ENEL S.p.A.
# luxottica, Luxottica Group
# ibest, Ibest Holding SpA
# Libero Professionista,
# Libero Professionista
# Ministero Della Difesa,
# Ministero Della Difesa
# World Food Programme,
# WFP
# Pirelli,
# Pirelli & C.
# Magneti Marelli,
# Marelli Automotive Systems
# BNL Gruppo BNP Paribas,Banca Monte Dei Paschi Di Siena
# Banca Monte Dei Paschi Di Siena,BMPS
# University Of Rome "La Sapienza",Uniroma1
# Gucci,Guccio Gucci FAO,Food And Agriculture Organization
# University of Padova, University of Padua
# Engineering Ingegneria Informatica Spa, EII
# University of Milan, Politecnico di Milano
# Prada, Prada Group
# Alitalia Compagnia Aerea Italiana Spa, Alitalia
# banca mediolanum,Banca Mediolanum SpA
# comau, Comau Spa
# iveco, Iveco Trucks
# costa crociere, Costa Crociere SpA
# ferrari, Ferrari NV
# Prysmian Group, Prysmian Spa
# Trenitalia SpA, Trenitalia SPA
# Me Stessa, MeS
# University of Florence, UNIFI
# Consiglio Nazionale delle Ricerche, CNR
# studio commercialista, Studio Commercialista Associati
# bancopopolare, Banca Popolare di Milano
# unipolassicurazionespa, UnipolSai Assicurazioni SpA
# armadeicarabinieridelvittorioemanueleIII, Arma dei Carabinieri del Vittorio Emanuele III
# gigroup, Gi Group
# ubi banca, UBI Banca Group, UniCredit Group
# banca fideuram, BNL Gruppo BNP Paribas
# sky italia, Sky Italia, Sky SpA
# ied istituto europeo di design, IED, Istituto Europeo di Design
# politecnico di milano, Politecnico di Milano, POLIMI
# Universita degli Studi di Torino, Politecnico Di Torino
# Ansaldo STS, Ansaldo
# Ansaldo STS, Alstom Transport
# Ansaldo STS, Finmeccanica
# Almaviva S.p.A., Almavita
# Almaviva S.p.A., Almavivio
# University of Naples Federico II, UNINA
# Dolce & Gabbana S.R.L., D&G
# Benetton Group, Benneton
# Alleanza Assicurazioni, ALI
# Wind, WIND TELCOM
# calzedonia group, Calzedonia Group SpA
# finecobank, Fineco Bank
# university of pisa, Università di Pisa
# mediaset, Mediaset SpA
# rfi rete ferroviaria italiana, Rete Ferroviaria Italiana
# diesel, Diesel N.V.
# fastweb, FastWeb S.p.A.
# university of rome "tor vergata", Università degli Studi di Roma Tor Vergata
# whirlpool emea, Whirlpool Europe
# danieli, Danieli & C. Officine Meccaniche SpA
# mondadori, Mondadori Editore
# mondadori, Mondadori Group
# comune, Comune di Roma
# comune, Municipality of Rome
# inail, Istituto Nazionale per l'Assicurazione contro gli Infortuni sul Lavoro
# inail, National Institute for Insurance against Workplace Accidents
# chiesi group, Chiesi Farmaceutici International NV
# allianz italia, Allianz Italia SpA
# University of Bologna, University of Bologna
# Barilla Group, Barilla Spa
# Banca D'Italia, Banca D'Italia SpA
# Bulgari, Bulgari SpA
# Piaggio Group, Piaggio & C. SpA
# menarini group,Menarini Group
# Libero Professionista Geometra,LPG
# PwC Italy,PricewaterhouseCoopers Italia
# Fincantieri S.p.A,Fincantieri SpA
# Polizia di Stato,State Police
# Universita' degli Studi di Milano-Bicocca, Universita' degli Studi di Milano Bicocca
# Salini Impregilo, Salimpi
# Egencia, Egencia Inc.
# NTT Data Italia, NTT Dat Italia
# Esselunga, Esselunga SpA
# University of Pavia, Universita' Degli Studi Di Pavia
# Agenzia Delle Entrate, Italian Revenue Agency
# Cheil Worldwide, Cheil Global
# Dental Clinic, None
# Università Degli Studi Di Bari, University Of Bari
# accenture italia, Accenture Italia Spa
# ermenegildo zegna group, Ermenegildo Zegna Group SpA
# ermenegilda zegna group, Ermenegildo Zegna Group SpA
# università degli studi roma tre, Universita' Degli Studi Roma Tre
# rina, RINA SpA
# ansaldo energia, Ansaldo Energia SpA
# banca popolare di milano, Bpm Group
# universita' degli studi di roma 'la sapienza', La Sapienza University
# valentino, Valentino Garavani
# indesit company, Indesit Company S.p.A., Indesit Company Italia, Indesit SpA
# salvatore ferragamo, Salvatore Ferragamo S.p.A., Ferragamo Group
# max mara fashion group,max mara group
# maserati,Maserati SpA
# BPER Banca,Banca Popolare dell'Emilia Romagna
# Astaldi,Astaldi SpA
# Università Bocconi,Politecnico di Milano
# gruppo cariparma crédit agricole, Crédit Agricole Italy
# libre, Libre Group
# amplifon, Amplifon Group
# kpmg italy, KPMG Italy
# safilo, Safilo Group
# enel green power,enel green power spa
# marche sub di cristobal alvarez rodolfo,marche spA
# university of trento,uniTrento
# universita degli studi di palermo,palermo universita
# bonatti s.p.a.,bonatti spA
# unipol assicurazioni, Unipol
# unipol assicurazioni, UNIPOL
# università degli studi di modena e reggio emilia, University of Modena and Reggio Emilia
# università degli studi di modena e reggio emilia, UniMoRe
# decathlon italia, Decathlon Italia
# decathlon italia, DECATHLON ITALIA
# avio aero, Avio Aero
# avio aero, AVIO AERO
# business integration partners, Business Integration Partners
# business integration partners, BIP
# studio tecnico ing. riccardo tognarini e centro promozionale efficienza in edilizia,studi tognarini & c.s.a.
# Unicredit Business Integrated Solutions,UBIS
# Reale Mutua Assicurazioni,RMA
# RCS Mediagroup, RCS
# Fendi,FENDI
# il sole 24 ore, il sole 24ore
# enea, ENEA SpA
# Brembo S.p.A., Brembo Spa
# Banca BPM, Banca Popolare di Milano
# Lavazza, Lavazza SpA
# geox, Geox SpA
# geox, Geox Italia
# h3g, H3G
# h3g, Wind Tre
# credem banca, Credem Banca
# credem banca, Credem
# ariston thermo group, Ariston Thermo Group
# ariston thermo group, Ariston
# deloitte italia, Deloitte Italia
# deloitte italia, Deloitte Consulting Italia
# ferrovie dello stato s.p.a., Ferrovie dello Stato Italiane
# gruppo campari, Campari Group
# sirti, Sirti SpA
# ministero delle infrastrutture e trasporti, Ministry of Infrastructure and Transport
# a2a, A2A Spa
# banca generali,banca generali spa
# banca generali,BG
# Cattolica Assicurazioni,Cattolica
# Lidl Italia,Lidl
# Provincia Autonoma di Trento,PT
# Zambon,Zambon Spa
# bottega veneta,Bottega Veneta
# bottega veneta,Bottega V
# kiko milano,Kiko Milano
# kiko milano,KIKO MILANO
# comune di roma,Comune di Roma
# comune di roma,CMR
# deutsche bank italia,Deutsche Bank Italia
# deutsche bank italia,DBI
# anas,ANAS
# Croce Rossa Italiana, Italian Red Cross
# Scuola Superiore Della Pubblica Amministrazione, Scuola Normale Superiore
# Automobili Lamborghini S.p.A., Lamborghini SPA
# SogeFi Group, SogeFi Spa
# SIA S.p.A., Istituto Centrale delle Banche Popolari Italiane
# policlinico umberto i,policlinico Umberto I di Bologna
# Datalogic,Datalogic S.p.A.,Daltec, Daltec S.p.A.
# Scuola Normale Superiore Scuola Normale Superiore di Pisa
# Technogym, Technogym SpA
# University of Verona, Università degli Studi di Verona
# wind tre, Wind Tre
# wind tre, Wind 3G
# randstad italia, Randstad Italia
# randstad italia, Randstad Holding Italy
# comdata spa, Comdata SpA
# comdata spa, COMDATA SPA
# regione emilia-romagna, Regione Emilia-Romagna
# regione emilia-romagna, Region of Emilia-Romagna
# italtel, Italtel
# italtel, ItalTel Spa
# libera professione, Libera Professione
# APSS Trento, Alto Adige Province of South Tyrol Service Trentino
# CRIF, CRIF - Credit Information Protection
# Università Politecnico Delle Marche, Università Politecnica delle Marche
# Edison Spa, Edison SpA
# seat pagine gialle spa, Seat Pagina Gialle Spa
# infn, INFN
# banca ifis, Banca IFIS
# regione lazio, Regione Lazio
# istituto clinico humanitas, Istituto Clinico Humanitas
# psicologia,
# psicologia
# ilva spa,
# ILVA SPA, ILVA SpA
# azimut,
# azimut
# credito valtellinese,
# Credit Valtellinese, Credito Valtellinese Spa
# hera,
# Hera Holding, Hera Group
# itariaonline, Italia Online
# angelini, Angelini Spa
# diasorin, Diasorin Spa
# ministero dei beni e delle attività culturali e del turismo, MiBACT
# permasteelisa spa, Permasteelisa SpA
# studio professionale,BTICINO
# ATAc SPA,Atac Spa
# BTICINO,Bticino SpA
# TERNA,Terna S.p.A.
# RAI-Radiotelevisione Italiana S.p.A.,Rai Spa
# axa assicurazioni, AXA Assicurazioni S.p.A., AXA Italy
# exprivia, Expivia, Expivia SpA
# indipendente, Indipendente, Indipendente S.r.l.
# miroglio, Miroglio, Gruppo Miroglio S.p.A.
# electrolux professional, Electrolux Professional
# electrolux professional, ELPRO
# Banca Popolare di Vicenza, BPD
# Istituto Italiano di Tecnologia, IIT
# Scuola Superiore Sant'Anna, SSDA
# Italcementi Group, Italmobiliare Group
# artesana group, artsana Group
# Istituto Nazionale di Statistica, ISTAT
# Universita' degli Studi di Catania, University of Catania
# Banca Popolare di Vicenza, Veneto Banca
# Gruppo Generali Assicurazioni S.p.A., Groupama Assicurazioni S.p.A.
# ovs, Officine Meccaniche Veloci Srl
# University of Messina, UNIME
# Loro Piana, LORO PLANA
# International Fund for Agricultural Development, IFAD
# FPT Industrial, FIAT POWER TRAINING INTERNATIONAL N.V., Fiat Powertrain Technologies NV
# fondazione don carlo gnocchi onlus, Fondazione Don Carlo Gnocchi Onlus
# de'l, De'Longhi
# chebanca!, Banca CheBanca!
# chebanca!, Mediobanca
# gruppo banca sella, Banca Sella
# gruppo banca sella, Cassa di Risparmio di Biella
# gruppo banca sella, CariChè
# gruppo banca sella, BCC Group
# gruppo banca sella, UBI Banca
# SNAM Rete Gas, Snam Rete Gas
# SNAM Rete Gas, SNAM ReteGas
# SNAM Rete Gas, Snam Rete Gas Spa
# bracco, Bracco Italia
# acea spa, ACEA Spa
# varie, Various
# moncler, Moncler SpA
# autostrade per l italia, Autostrada del Brennero SpA
# fondiaria sai, Fondiaria Sai
# mcs, Media Market
# comune di bologna, Comune Di Bologna
# mediamarket spa, MediaMarket Spa
# agos ducato spa, Agos Ducato SpA
# University of Calabria, Universita' di Calabria
# Law Firm, Lawfirm
# Versalis Spa, Versalis SPA
# Regione Piemonte, Regione del Piemonte
# SSC, SSC Napoli
# banca imi, Banca IMI
# bieße group, BIESS Group
# medisur, Medisur
# enav, ENAV
# university of salerno, Università degli Studi di Salerno
# candy hoover group,candyhoovergroup
# luiss,LUISS Guido Carli University
# university of perugia,Università degli Studi di Perugia
# team system,TeamSystem
# universita' del salento,Università del Salento
# La Perla, La Perla Group
# Ericsson It Solutions & Services Spa, Ericsson Italy
# Ducati Motor Holding, Ducati
# Zucchetti, Zucchetti Sistemi Spa
# Azienda Ospedaliera Universitaria Integrata Verona, AOUIVR
# sisal s.p.a., SISAL
# sanpaolo invest sim s.p.a., SANPAOLO INVEST SIM
# unieuro, UNIEURO
# fondazione i.r.c.c.s. policlinico san matteo pavia, POLICLINICO SAN MATTEO PAVIA
# fincons group, FINCONS GROUP
# banca carige spa, Banca Carige Spa
# banca carige spa, Banca di Credito Cooperativo di Genova e Provincia
# techedge group, Techedge Group
# techedge group, Techedge
# sogei, SOGEI
# sogei, Società Gestione Esercizio Istituti Industriali
# maire tecnimont, Maire Tecnimont
# maire tecnimont, Technip Italia SpA
# maire tecnimont, Tecnimont Spa
# maire tecnimont, Tecnimont N.V.
# mediobanca, Mediobanca
# mediobanca, Mediocredito Italiano Spa
# unipol banca, Unipol Banca Group
# unipol banca, UNIPOL BANCA
# unipol banca, UNIPOL SPA
# conad, COOP Nord Mezzogiorno
# conad, Conad Adria
# recordati, Recordati Industrie Farmaceutiche Agricole SpA
# recordati, Recordati S.p.A.
# recordati, RECORDDATI
# recordati, RECOR
# recordati, Ratiopharm
# comune di firenze, Comune di Firenze
# university of siena, Università degli Studi di Siena
# university of siena, University of Siena
# fater s.p.a., Fater SpA
# natuzzi, Natuzzi Italia
# sol, Sol Group
# banca popolare di sondrio, Banca Popolare di Sondrio
# università degli studi di cagliari, Universita' Degli Studi Di Cagliari
# coop alleanza 3.0, coop alleanza 3.0
# presidenza del consiglio dei ministri, presidente del consiglio dei ministri
# sara assicurazioni s.p.a., Sara Assicurazioni SPA
# sacmi, SACMI
# ieo istituto europeo di oncologia, IEO Istituto Europeo di Oncologia
# Vittoria Assicurazioni, Vittoria Insurance Company
# Mine, Mine Italia
# SCM Group SPA, SCM Spa
# SDL Centro Studi S.P.A., SDL Centro Studi
# Italferr S.P.A., Italferr Spa
# altene italiana, altene italia
# italia lavoro, lavori italia
# csi piemonte, csi pietmonte
# sielte s.p.a., sielte spa
# sda express courier, sda expresscourier
# findomestic banca spa,Findomestic Banca Spa
# sorin group,SORIN Group
# camera dei deputati,Camera Dei Deputati
# regione autonoma friuli venezia giulia,Regione Autonoma Friuli Venezia Giulia
# sda bocconi school of management,SDA Bocconi School of Management
# frau,, frau
# coldiretti,, coldiretti
# wolters kluwer italia,, Wolters Kluwer Italia
# marcolin,, Marcolin
# university of udine,, University of Udine
# bonfiglioli, Bonfiglioli Power Transmission S.p.A.
# Mondo Convenienza, Mondo Convenienza S.p.A.
# Zoppas Industries Heating Element Technologies, Zoppas Group
# Università degli Studi di Parma, Università di Parma
# Same Deutz-Fahr Group, SAME Deutz-Harvester, Same Deutz-Fahr, SAME Deutz-Harvester Group
# telespazio,Thales Alenia Space
# furla,FURLA Spa
# würth italia,Würth Italia SpA
# gea,GEA Group AG
# manutencoop,Manutencoop Coop Società Cooperativa Arredata e Gestione Servizi

# %%
import csv

lines = dataset_alias.split("\n")

# Specify the file path
file_path = "dataset.csv"

# Open the CSV file in write mode with newline='' to ensure correct newline handling
with open(file_path, "w", newline='') as file:
    # Create a CSV writer object
    writer = csv.writer(file)

    # Write each line to the CSV file
    for line in lines:
        # Split the line into fields based on the comma ','
        fields = line.split(",")
        # Write the fields to the CSV file
        if len(fields)==2:
          writer.writerow(fields)
        elif len(fields)>2:
          writer.writerow(fields[0:2])
        else:
          print('Warning, only one name')
# Out:
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name
# Warning, only one name

# %%
pd.read_csv(file_path)
# Out:
#        Company Name                                              Alias
# 0    telecom italia                              Telecom Italia S.p.A.
# 1    poste italiane                                     Poste Italiane
# 2              enel                                        ENEL S.p.A.
# 3         luxottica                                    Luxottica Group
# 4             ibest                                  Ibest Holding SpA
# ..              ...                                                ...
# 338      telespazio                                Thales Alenia Space
# 339           furla                                          FURLA Spa
# 340    würth italia                                   Würth Italia SpA
# 341             gea                                       GEA Group AG
# 342     manutencoop  Manutencoop Coop Società Cooperativa Arredata ...
#
# [343 rows x 2 columns]
